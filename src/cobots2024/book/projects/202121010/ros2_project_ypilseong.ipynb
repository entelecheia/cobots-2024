# %%
import os
import sys
import yaml
import rclpy
import random
import numpy as np
from geometry_msgs.msg import PoseStamped, Pose
from moveit.planning import MoveItPy
from moveit.core.robot_state import RobotState
from moveit_configs_utils import MoveItConfigsBuilder
from ament_index_python.packages import get_package_share_directory
from rclpy.node import Node
from trajectory_msgs.msg import JointTrajectory, JointTrajectoryPoint

# we need to specify our moveit_py config at the top of each notebook we use. 
# this is since we will start spinning a moveit_py node within this notebook.

moveit_config = (
        MoveItConfigsBuilder(robot_name="panda", package_name="moveit_resources_panda_moveit_config")
        .robot_description(file_path="config/panda.urdf.xacro")
        .trajectory_execution(file_path="config/gripper_moveit_controllers.yaml")
        .moveit_cpp(
            file_path=os.path.join(
                get_package_share_directory("moveit2_tutorials"),
                "config",
                "jupyter_notebook_prototyping.yaml"
        )
    )
    .to_moveit_configs()
    ).to_dict()

# %%
# initialise rclpy (only for logging purposes)
rclpy.init()

# instantiate moveit_py instance and a planning component for the panda_arm
panda = MoveItPy(node_name="moveit_py", config_dict=moveit_config)
panda_arm = panda.get_planning_component("panda_arm")
panda_gripper = panda.get_planning_component("hand")
# Out:
# [INFO] [1719044930.660967635] [moveit_cpp_initializer]: Initialize rclcpp
# [INFO] [1719044930.661607961] [moveit_cpp_initializer]: Initialize node parameters
# [INFO] [1719044930.733632694] [moveit_cpp_initializer]: params_filepath: /tmp/launch_params_l37y8zsz
# [INFO] [1719044930.733713494] [moveit_cpp_initializer]: Initialize node and executor
# [INFO] [1719044930.959551319] [moveit_cpp_initializer]: Spin separate thread
# [INFO] [1719044930.963169161] [moveit_rdf_loader.rdf_loader]: Loaded robot model in 0.00342717 seconds
# [INFO] [1719044930.963201127] [moveit_robot_model.robot_model]: Loading robot model 'panda'...
# [INFO] [1719044931.019149417] [moveit_kinematics_base.kinematics_base]: Joint weights for group 'panda_arm': 1 1 1 1 1 1 1
# [INFO] [1719044931.049581449] [moveit.ros_planning_interface.moveit_cpp]: Listening to '/joint_states' for joint states
# [INFO] [1719044931.052932195] [moveit_ros.current_state_monitor]: Listening to joint states on topic '/joint_states'
# [INFO] [1719044931.057833476] [moveit_ros.planning_scene_monitor.planning_scene_monitor]: Listening to '/moveit_cpp/planning_scene_monitor' for attached collision objects
# [INFO] [1719044931.060089735] [moveit_ros.planning_scene_monitor.planning_scene_monitor]: Publishing maintained planning scene on '/moveit_cpp/monitored_planning_scene'
# [INFO] [1719044931.060370533] [moveit_ros.planning_scene_monitor.planning_scene_monitor]: Starting planning scene monitor
# [INFO] [1719044931.062801012] [moveit_ros.planning_scene_monitor.planning_scene_monitor]: Listening to '/moveit_cpp/publish_planning_scene'
# [INFO] [1719044931.062823632] [moveit_ros.planning_scene_monitor.planning_scene_monitor]: Starting world geometry update monitor for collision objects, attached objects, octomap updates.
# [INFO] [1719044931.063841874] [moveit_ros.planning_scene_monitor.planning_scene_monitor]: Listening to 'collision_object'
# [INFO] [1719044931.064920840] [moveit_ros.planning_scene_monitor.planning_scene_monitor]: Listening to 'planning_scene_world' for planning scene world geometry
# [WARN] [1719044931.085823765] [moveit.ros.occupancy_map_monitor.middleware_handle]: Resolution not specified for Octomap. Assuming resolution = 0.1 instead
# [ERROR] [1719044931.085883883] [moveit.ros.occupancy_map_monitor.middleware_handle]: No 3D sensor plugin(s) defined for octomap updates
# [INFO] [1719044931.162667770] [moveit.ros_planning.planning_pipeline]: Using planning interface 'OMPL'
# [INFO] [1719044931.187786213] [moveit_ros.add_time_optimal_parameterization]: Param 'ompl.path_tolerance' was not set. Using default value: 0.100000
# [INFO] [1719044931.187817468] [moveit_ros.add_time_optimal_parameterization]: Param 'ompl.resample_dt' was not set. Using default value: 0.100000
# [INFO] [1719044931.187824493] [moveit_ros.add_time_optimal_parameterization]: Param 'ompl.min_angle_change' was not set. Using default value: 0.001000
# [INFO] [1719044931.187856469] [moveit_ros.fix_workspace_bounds]: Param 'ompl.default_workspace_bounds' was not set. Using default value: 10.000000
# [INFO] [1719044931.187876796] [moveit_ros.fix_start_state_bounds]: Param 'ompl.start_state_max_bounds_error' was set to 0.100000
# [INFO] [1719044931.187883863] [moveit_ros.fix_start_state_bounds]: Param 'ompl.start_state_max_dt' was not set. Using default value: 0.500000
# [INFO] [1719044931.187896841] [moveit_ros.fix_start_state_collision]: Param 'ompl.start_state_max_dt' was not set. Using default value: 0.500000
# [INFO] [1719044931.187903558] [moveit_ros.fix_start_state_collision]: Param 'ompl.jiggle_fraction' was not set. Using default value: 0.020000
# [INFO] [1719044931.187912525] [moveit_ros.fix_start_state_collision]: Param 'ompl.max_sampling_attempts' was not set. Using default value: 100
# [INFO] [1719044931.187926186] [moveit.ros_planning.planning_pipeline]: Using planning request adapter 'Add Time Optimal Parameterization'
# [INFO] [1719044931.187933134] [moveit.ros_planning.planning_pipeline]: Using planning request adapter 'Resolve constraint frames to robot links'
# [INFO] [1719044931.187938097] [moveit.ros_planning.planning_pipeline]: Using planning request adapter 'Fix Workspace Bounds'
# [INFO] [1719044931.187993012] [moveit.ros_planning.planning_pipeline]: Using planning request adapter 'Fix Start State Bounds'
# [INFO] [1719044931.188001507] [moveit.ros_planning.planning_pipeline]: Using planning request adapter 'Fix Start State In Collision'
# [INFO] [1719044931.188006525] [moveit.ros_planning.planning_pipeline]: Using planning request adapter 'Fix Start State Path Constraints'
# [INFO] [1719044931.360082384] [moveit.plugins.moveit_simple_controller_manager]: Added FollowJointTrajectory controller for panda_arm_controller
# [INFO] [1719044931.360170966] [moveit.plugins.moveit_simple_controller_manager]: Max effort set to 0.0
# [INFO] [1719044931.363848069] [moveit.plugins.moveit_simple_controller_manager]: Added GripperCommand controller for panda_hand_controller
# [INFO] [1719044931.364123304] [moveit.plugins.moveit_simple_controller_manager]: Returned 2 controllers in list
# [INFO] [1719044931.364153965] [moveit.plugins.moveit_simple_controller_manager]: Returned 2 controllers in list
# [INFO] [1719044931.364878723] [moveit_ros.trajectory_execution_manager]: Trajectory execution is managing controllers

# %%
def plan_and_execute(
    robot,
    planning_component,
    single_plan_parameters=None,
    multi_plan_parameters=None,
):
    """A helper function to plan and execute a motion."""
    # plan to goal
    if multi_plan_parameters is not None:
        plan_result = planning_component.plan(
            multi_plan_parameters=multi_plan_parameters
        )
    elif single_plan_parameters is not None:
        plan_result = planning_component.plan(
            single_plan_parameters=single_plan_parameters
        )
    else:
        plan_result = planning_component.plan()

    # execute the plan
    if plan_result:
        robot_trajectory = plan_result.trajectory
        robot.execute(robot_trajectory, controllers=[])
    else:
        print("Planning failed")
        


# 특정 좌표로 이동시키는 함수
def move_to_pose(robot, planning_component, pose):
    planning_component.set_start_state_to_current_state()
    planning_component.set_goal_state(pose_stamped_msg=pose, pose_link="panda_link8")
    plan_and_execute(robot, planning_component)

# 그리퍼를 여는 함수 (가상의 함수로 대체)
def open_gripper():
    panda_gripper.set_start_state_to_current_state()
    panda_gripper.set_goal_state("open")
    plan_and_execute(panda, panda_gripper)
    print("Gripper opened")

# 그리퍼를 닫는 함수 (가상의 함수로 대체)
def close_gripper():
    panda_gripper.set_start_state_to_current_state()
    panda_gripper.set_goal_state("close")
    plan_and_execute(panda, panda_gripper)
    print("Gripper closed")
   
    
place_pose_xy = [(-0.2, -0.2), (-0.25, -0.2),(-0.2, -0.25),(-0.25,-0.25),(-0.2,-0.3),(-0.25,-0.3)]

# 초기 위치 정의 (특정 좌표로 설정)
initial_pose = PoseStamped()
initial_pose.header.frame_id = "panda_link0"
initial_pose.pose.orientation.w = 0.0
initial_pose.pose.orientation.x = 0.0
initial_pose.pose.orientation.y = 1.0
initial_pose.pose.orientation.z = 0.0
initial_pose.pose.position.x = 0.3
initial_pose.pose.position.y = 0.3
initial_pose.pose.position.z = 0.7

# 목표 좌표 정의
pick_pose = PoseStamped()
pick_pose.header.frame_id = "panda_link0"
pick_pose.pose.orientation.w = 0.0
pick_pose.pose.orientation.z = 0.0
pick_pose.pose.orientation.y = 1.0
pick_pose.pose.orientation.z = 0.0
#pick_pose.pose.position.x = -0.28
#pick_pose.pose.position.y = -0.2
pick_pose.pose.position.z = 0.1

place_pose = PoseStamped()
place_pose.header.frame_id = "panda_link0"
place_pose.pose.orientation.w = 0.0
place_pose.pose.orientation.x = 0.0
place_pose.pose.orientation.y = 1.0
place_pose.pose.orientation.z = 0.0
#place_pose.pose.position.x = 0.5
#place_pose.pose.position.y = 0.0
place_pose.pose.position.z = 0.3


for i in range(6):
    # 1. 초기 위치로 이동
    move_to_pose(panda, panda_arm, initial_pose)

    # 2. 특정 위치로 이동
    x = random.uniform(0.0, 0.5)  # Random x position
    y = random.uniform(0.0, 0.5)  # Random y position

    pick_pose.pose.position.x = x
    pick_pose.pose.position.y = y
    move_to_pose(panda, panda_arm, pick_pose)

    # 3. gripper 통해 객체 잡기 (구현x)
    open_gripper()

    close_gripper()

    x, y = place_pose_xy[i]
    place_pose.pose.position.x = x
    place_pose.pose.position.y = y
    
    # 4. 객체를 특정 위치로 이동
    move_to_pose(panda, panda_arm, place_pose)
    
    # 5. 객체 놓기
    open_gripper()


move_to_pose(panda, panda_arm, initial_pose)
# Out:
# [WARN] [1719045259.434156467] [moveit_py]: Parameter 'plan_request_params.planner_id' not found in config use default value instead, check parameter type and namespace in YAML file
[moveit.plugins.moveit_simple_controller_manager]: Returned 2 controllers in list
# [INFO] [1719045287.100262303] [moveit_ros.trajectory_execution_manager]: Validating trajectory with allowed_start_tolerance 0.01
# [INFO] [1719045287.101577898] [moveit_ros.trajectory_execution_manager]: Starting trajectory execution ...
# ...
# [INFO] [1719045292.043338785] [moveit.simple_controller_manager.follow_joint_trajectory_controller_handle]: Goal request accepted!
# [INFO] [1719045294.394813645] [moveit.simple_controller_manager.follow_joint_trajectory_controller_handle]: Controller 'panda_arm_controller' successfully finished
# [INFO] [1719045294.421731941] [moveit_ros.trajectory_execution_manager]: Completed trajectory execution with status SUCCEEDED ...
# [WARN] [1719045294.422442081] [moveit_py]: Parameter 'plan_request_params.planner_id' not found in config use default value instead, check parameter type and namespace in YAML file
# [WARN] [1719045294.422595936] [moveit_py]: Parameter 'plan_request_params.planning_time' not found in config use default value instead, check parameter type and namespace in YAML file
# [INFO] [1719045294.424113542] [moveit.ompl_planning.model_based_planning_context]: Planner configuration 'hand' will use planner 'geometric::RRTConnect'. Additional configuration parameters will be set when the planner is constructed.
# [INFO] [1719045294.483127135] [moveit.plugins.moveit_simple_controller_manager]: Returned 2 controllers in list
# [INFO] [1719045294.483176221] [moveit.plugins.moveit_simple_controller_manager]: Returned 2 controllers in list
# [INFO] [1719045294.483201571] [moveit.plugins.moveit_simple_controller_manager]: Returned 2 controllers in list
# [INFO] [1719045294.483248831] [moveit.plugins.moveit_simple_controller_manager]: Returned 2 controllers in list
# [INFO] [1719045294.483268320] [moveit_ros.trajectory_execution_manager]: Validating trajectory with allowed_start_tolerance 0.01
# [INFO] [1719045294.491722640] [moveit_ros.trajectory_execution_manager]: Starting trajectory execution ...
# [INFO] [1719045294.491862983] [moveit.plugins.moveit_simple_controller_manager]: Returned 2 controllers in list
# [INFO] [1719045294.492068620] [moveit.plugins.moveit_simple_controller_manager]: Returned 2 controllers in list
# [INFO] [1719045294.572169647] [moveit_ros.trajectory_execution_manager]: Completed trajectory execution with status SUCCEEDED ...
# [WARN] [1719045294.579702223] [moveit_py]: Parameter 'plan_request_params.planner_id' not found in config use default value instead, check parameter type and namespace in YAML file
# [WARN] [1719045294.579811470] [moveit_py]: Parameter 'plan_request_params.planning_time' not found in config use default value instead, check parameter type and namespace in YAML file
# [INFO] [1719045294.580940510] [moveit.ompl_planning.model_based_planning_context]: Planner configuration 'panda_arm' will use planner 'geometric::RRTConnect'. Additional configuration parameters will be set when the planner is constructed.
# [INFO] [1719045294.660544572] [moveit.plugins.moveit_simple_controller_manager]: Returned 2 controllers in list
# [INFO] [1719045294.660593691] [moveit.plugins.moveit_simple_controller_manager]: Returned 2 controllers in list
# [INFO] [1719045294.660632481] [moveit.plugins.moveit_simple_controller_manager]: Returned 2 controllers in list
# [INFO] [1719045294.660643353] [moveit.plugins.moveit_simple_controller_manager]: Returned 2 controllers in list
# [INFO] [1719045294.660673553] [moveit_ros.trajectory_execution_manager]: Validating trajectory with allowed_start_tolerance 0.01
# [INFO] [1719045294.671725993] [moveit_ros.trajectory_execution_manager]: Starting trajectory execution ...
# [INFO] [1719045294.671867063] [moveit.plugins.moveit_simple_controller_manager]: Returned 2 controllers in list
# [INFO] [1719045294.671918876] [moveit.plugins.moveit_simple_controller_manager]: Returned 2 controllers in list
# [INFO] [1719045294.672238144] [moveit.simple_controller_manager.follow_joint_trajectory_controller_handle]: sending trajectory to panda_arm_controller
# [INFO] [1719045294.673467864] [moveit.simple_controller_manager.follow_joint_trajectory_controller_handle]: panda_arm_controller started execution
# [INFO] [1719045294.673496513] [moveit.simple_controller_manager.follow_joint_trajectory_controller_handle]: Goal request accepted!
# [INFO] [1719045296.474827805] [moveit.simple_controller_manager.follow_joint_trajectory_controller_handle]: Controller 'panda_arm_controller' successfully finished
# [INFO] [1719045296.502448815] [moveit_ros.trajectory_execution_manager]: Completed trajectory execution with status SUCCEEDED ...
# [WARN] [1719045296.506570245] [moveit_py]: Parameter 'plan_request_params.planner_id' not found in config use default value instead, check parameter type and namespace in YAML file
# [WARN] [1719045296.506680356] [moveit_py]: Parameter 'plan_request_params.planning_time' not found in config use default value instead, check parameter type and namespace in YAML file
# [INFO] [1719045296.507830095] [moveit.ompl_planning.model_based_planning_context]: Planner configuration 'panda_arm' will use planner 'geometric::RRTConnect'. Additional configuration parameters will be set when the planner is constructed.
# [INFO] [1719045296.594552121] [moveit.plugins.moveit_simple_controller_manager]: Returned 2 controllers in list
# [INFO] [1719045296.594612554] [moveit.plugins.moveit_simple_controller_manager]: Returned 2 controllers in list
# [INFO] [1719045296.594666680] [moveit.plugins.moveit_simple_controller_manager]: Returned 2 controllers in list
# [INFO] [1719045296.594677350] [moveit.plugins.moveit_simple_controller_manager]: Returned 2 controllers in list
# [INFO] [1719045296.594707314] [moveit_ros.trajectory_execution_manager]: Validating trajectory with allowed_start_tolerance 0.01
# [INFO] [1719045296.602215165] [moveit_ros.trajectory_execution_manager]: Starting trajectory execution ...
# [INFO] [1719045296.602529239] [moveit.plugins.moveit_simple_controller_manager]: Returned 2 controllers in list
# [INFO] [1719045296.602618322] [moveit.plugins.moveit_simple_controller_manager]: Returned 2 controllers in list
# [INFO] [1719045296.603272727] [moveit.simple_controller_manager.follow_joint_trajectory_controller_handle]: sending trajectory to panda_arm_controller
# [INFO] [1719045296.605703160] [moveit.simple_controller_manager.follow_joint_trajectory_controller_handle]: panda_arm_controller started execution
# [INFO] [1719045296.605754598] [moveit.simple_controller_manager.follow_joint_trajectory_controller_handle]: Goal request accepted!
# [INFO] [1719045298.707529864] [moveit.simple_controller_manager.follow_joint_trajectory_controller_handle]: Controller 'panda_arm_controller' successfully finished
# [INFO] [1719045298.732861268] [moveit_ros.trajectory_execution_manager]: Completed trajectory execution with status SUCCEEDED ...
# [WARN] [1719045298.735215209] [moveit_py]: Parameter 'plan_request_params.planner_id' not found in config use default value instead, check parameter type and namespace in YAML file
# [WARN] [1719045298.735335136] [moveit_py]: Parameter 'plan_request_params.planning_time' not found in config use default value instead, check parameter type and namespace in YAML file
# [INFO] [1719045298.736348060] [moveit.ompl_planning.model_based_planning_context]: Planner configuration 'hand' will use planner 'geometric::RRTConnect'. Additional configuration parameters will be set when the planner is constructed.
# [INFO] [1719045298.766628664] [moveit.plugins.moveit_simple_controller_manager]: Returned 2 controllers in list
# [INFO] [1719045298.766694360] [moveit.plugins.moveit_simple_controller_manager]: Returned 2 controllers in list
# [INFO] [1719045298.766718983] [moveit.plugins.moveit_simple_controller_manager]: Returned 2 controllers in list
# [INFO] [1719045298.766730098] [moveit.plugins.moveit_simple_controller_manager]: Returned 2 controllers in list
# [INFO] [1719045298.766747992] [moveit_ros.trajectory_execution_manager]: Validating trajectory with allowed_start_tolerance 0.01
# [INFO] [1719045298.772588468] [moveit_ros.trajectory_execution_manager]: Starting trajectory execution ...
# [INFO] [1719045298.772687553] [moveit.plugins.moveit_simple_controller_manager]: Returned 2 controllers in list
# [INFO] [1719045298.772731485] [moveit.plugins.moveit_simple_controller_manager]: Returned 2 controllers in list
# [INFO] [1719045298.852180156] [moveit_ros.trajectory_execution_manager]: Completed trajectory execution with status SUCCEEDED ...
# [WARN] [1719045298.853015034] [moveit_py]: Parameter 'plan_request_params.planner_id' not found in config use default value instead, check parameter type and namespace in YAML file
# [WARN] [1719045298.853093182] [moveit_py]: Parameter 'plan_request_params.planning_time' not found in config use default value instead, check parameter type and namespace in YAML file
# [INFO] [1719045298.853700546] [moveit.ompl_planning.model_based_planning_context]: Planner configuration 'hand' will use planner 'geometric::RRTConnect'. Additional configuration parameters will be set when the planner is constructed.
# [INFO] [1719045298.904252593] [moveit.plugins.moveit_simple_controller_manager]: Returned 2 controllers in list
# [INFO] [1719045298.904303556] [moveit.plugins.moveit_simple_controller_manager]: Returned 2 controllers in list
# [INFO] [1719045298.904332981] [moveit.plugins.moveit_simple_controller_manager]: Returned 2 controllers in list
# [INFO] [1719045298.904343714] [moveit.plugins.moveit_simple_controller_manager]: Returned 2 controllers in list
# [INFO] [1719045298.904364299] [moveit_ros.trajectory_execution_manager]: Validating trajectory with allowed_start_tolerance 0.01
# [INFO] [1719045298.913422908] [moveit_ros.trajectory_execution_manager]: Starting trajectory execution ...
# [INFO] [1719045298.913506392] [moveit.plugins.moveit_simple_controller_manager]: Returned 2 controllers in list
# [INFO] [1719045298.913587997] [moveit.plugins.moveit_simple_controller_manager]: Returned 2 controllers in list
# [INFO] [1719045298.991348296] [moveit_ros.trajectory_execution_manager]: Completed trajectory execution with status SUCCEEDED ...
# [WARN] [1719045298.992729718] [moveit_py]: Parameter 'plan_request_params.planner_id' not found in config use default value instead, check parameter type and namespace in YAML file
# [WARN] [1719045298.992786893] [moveit_py]: Parameter 'plan_request_params.planning_time' not found in config use default value instead, check parameter type and namespace in YAML file
# [INFO] [1719045298.993501826] [moveit.ompl_planning.model_based_planning_context]: Planner configuration 'panda_arm' will use planner 'geometric::RRTConnect'. Additional configuration parameters will be set when the planner is constructed.
# [INFO] [1719045299.087208344] [moveit.plugins.moveit_simple_controller_manager]: Returned 2 controllers in list
# [INFO] [1719045299.087262563] [moveit.plugins.moveit_simple_controller_manager]: Returned 2 controllers in list
# [INFO] [1719045299.087308964] [moveit.plugins.moveit_simple_controller_manager]: Returned 2 controllers in list
# [INFO] [1719045299.087320628] [moveit.plugins.moveit_simple_controller_manager]: Returned 2 controllers in list
# [INFO] [1719045299.087353658] [moveit_ros.trajectory_execution_manager]: Validating trajectory with allowed_start_tolerance 0.01
# [INFO] [1719045299.091583497] [moveit_ros.trajectory_execution_manager]: Starting trajectory execution ...
# [INFO] [1719045299.091671999] [moveit.plugins.moveit_simple_controller_manager]: Returned 2 controllers in list
# [INFO] [1719045299.091703030] [moveit.plugins.moveit_simple_controller_manager]: Returned 2 controllers in list
# [INFO] [1719045299.091870092] [moveit.simple_controller_manager.follow_joint_trajectory_controller_handle]: sending trajectory to panda_arm_controller
# [INFO] [1719045299.092967449] [moveit.simple_controller_manager.follow_joint_trajectory_controller_handle]: panda_arm_controller started execution
# [INFO] [1719045299.092996807] [moveit.simple_controller_manager.follow_joint_trajectory_controller_handle]: Goal request accepted!
# [INFO] [1719045300.944444070] [moveit.simple_controller_manager.follow_joint_trajectory_controller_handle]: Controller 'panda_arm_controller' successfully finished
# [INFO] [1719045300.971638112] [moveit_ros.trajectory_execution_manager]: Completed trajectory execution with status SUCCEEDED ...
# [WARN] [1719045300.972606681] [moveit_py]: Parameter 'plan_request_params.planner_id' not found in config use default value instead, check parameter type and namespace in YAML file
# [WARN] [1719045300.972680419] [moveit_py]: Parameter 'plan_request_params.planning_time' not found in config use default value instead, check parameter type and namespace in YAML file
# [INFO] [1719045300.973374635] [moveit.ompl_planning.model_based_planning_context]: Planner configuration 'hand' will use planner 'geometric::RRTConnect'. Additional configuration parameters will be set when the planner is constructed.
# [INFO] [1719045301.007116827] [moveit.plugins.moveit_simple_controller_manager]: Returned 2 controllers in list
# [INFO] [1719045301.007189262] [moveit.plugins.moveit_simple_controller_manager]: Returned 2 controllers in list
# [INFO] [1719045301.007221006] [moveit.plugins.moveit_simple_controller_manager]: Returned 2 controllers in list
# [INFO] [1719045301.007231672] [moveit.plugins.moveit_simple_controller_manager]: Returned 2 controllers in list
# [INFO] [1719045301.007259331] [moveit_ros.trajectory_execution_manager]: Validating trajectory with allowed_start_tolerance 0.01
# [INFO] [1719045301.011770015] [moveit_ros.trajectory_execution_manager]: Starting trajectory execution ...
# [INFO] [1719045301.011897837] [moveit.plugins.moveit_simple_controller_manager]: Returned 2 controllers in list
# [INFO] [1719045301.011950480] [moveit.plugins.moveit_simple_controller_manager]: Returned 2 controllers in list
# [INFO] [1719045301.091720356] [moveit_ros.trajectory_execution_manager]: Completed trajectory execution with status SUCCEEDED ...
# [WARN] [1719045301.092846910] [moveit_py]: Parameter 'plan_request_params.planner_id' not found in config use default value instead, check parameter type and namespace in YAML file
# [WARN] [1719045301.092901118] [moveit_py]: Parameter 'plan_request_params.planning_time' not found in config use default value instead, check parameter type and namespace in YAML file
# [INFO] [1719045301.093610493] [moveit.ompl_planning.model_based_planning_context]: Planner configuration 'panda_arm' will use planner 'geometric::RRTConnect'. Additional configuration parameters will be set when the planner is constructed.
# [INFO] [1719045301.201958408] [moveit.plugins.moveit_simple_controller_manager]: Returned 2 controllers in list
# [INFO] [1719045301.202001867] [moveit.plugins.moveit_simple_controller_manager]: Returned 2 controllers in list
# [INFO] [1719045301.202039096] [moveit.plugins.moveit_simple_controller_manager]: Returned 2 controllers in list
# [INFO] [1719045301.202050818] [moveit.plugins.moveit_simple_controller_manager]: Returned 2 controllers in list
# [INFO] [1719045301.202096210] [moveit_ros.trajectory_execution_manager]: Validating trajectory with allowed_start_tolerance 0.01
# [INFO] [1719045301.211918222] [moveit_ros.trajectory_execution_manager]: Starting trajectory execution ...
# [INFO] [1719045301.212056773] [moveit.plugins.moveit_simple_controller_manager]: Returned 2 controllers in list
# [INFO] [1719045301.212146055] [moveit.plugins.moveit_simple_controller_manager]: Returned 2 controllers in list
# [INFO] [1719045301.212387887] [moveit.simple_controller_manager.follow_joint_trajectory_controller_handle]: sending trajectory to panda_arm_controller
# [INFO] [1719045301.213901736] [moveit.simple_controller_manager.follow_joint_trajectory_controller_handle]: panda_arm_controller started execution
# [INFO] [1719045301.213962367] [moveit.simple_controller_manager.follow_joint_trajectory_controller_handle]: Goal request accepted!
# [INFO] [1719045303.315696145] [moveit.simple_controller_manager.follow_joint_trajectory_controller_handle]: Controller 'panda_arm_controller' successfully finished
# [INFO] [1719045303.341962606] [moveit_ros.trajectory_execution_manager]: Completed trajectory execution with status SUCCEEDED ...

# %%
rclpy.shutdown()
